# %% [markdown]
# # Imports

# %%
import os
import pathlib
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import pickle

# %% [markdown]
# # Config

# %%
class CFG:
    seed = 888
    debug = False
    one_fold = False
    base_dir = pathlib.Path(".")
    path_train = base_dir / "train.csv"
    spec_dir =  "EEG_Spectrograms"
    transform = transforms.Resize((768, 768), antialias=False)
    model_name = "tf_efficientnet_b0.ns_jft_in1k"
    n_fold = 5
    epochs = 5
    batch_size = 8
    lr = 0.001

# %%
train_df = pd.read_csv("updated_train.csv")
train_df
# Out:
#             eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0       1628180742           0                       0.0          353733
# 1       1628180742           1                       6.0          353733
# 2       1628180742           2                       8.0          353733
# 3       1628180742           3                      18.0          353733
# 4       1628180742           4                      24.0          353733
# ...            ...         ...                       ...             ...
# 100779   351917269           6                      12.0      2147388374
# 100780   351917269           7                      14.0      2147388374
# 100781   351917269           8                      16.0      2147388374
# 100782   351917269           9                      18.0      2147388374
# 100783   351917269          10                      20.0      2147388374
#
#         spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                        0                               0.0   127492639
# 1                        1                               6.0  3887563113
# 2                        2                               8.0  1142670488
# 3                        3                              18.0  2718991173
# 4                        4                              24.0  3080632009
# ...                    ...                               ...         ...
# 100779                   6                              12.0  4195677307
# 100780                   7                              14.0   290896675
# 100781                   8                              16.0   461435451
# 100782                   9                              18.0  3786213131
# 100783                  10                              20.0  3642716176
#
#         patient_id expert_consensus  seizure_vote  lpd_vote  gpd_vote  \
# 0            42516          Seizure             3         0         0
# 1            42516          Seizure             3         0         0
# 2            42516          Seizure             3         0         0
# 3            42516          Seizure             3         0         0
# 4            42516          Seizure             3         0         0
# ...            ...              ...           ...       ...       ...
# 100779       10351             LRDA             0         0         0
# 100780       10351             LRDA             0         0         0
# 100781       10351             LRDA             0         0         0
# 100782       10351             LRDA             0         0         0
# 100783       10351             LRDA             0         0         0
#
#         lrda_vote  grda_vote  other_vote
# 0               0          0           0
# 1               0          0           0
# 2               0          0           0
# 3               0          0           0
# 4               0          0           0
# ...           ...        ...         ...
# 100779          3          0           0
# 100780          3          0           0
# 100781          3          0           0
# 100782          3          0           0
# 100783          3          0           0
#
# [100784 rows x 15 columns]

# %%
label_columns = train_df.filter(like="_vote").columns.to_list()
label_columns
# Out:
# ['seizure_vote',
#  'lpd_vote',
#  'gpd_vote',
#  'lrda_vote',
#  'grda_vote',
#  'other_vote']

# %%
PATH = 'E:/HMS2024/train_spec_for_paper/'
files = os.listdir(PATH)
print(f'There are {len(files)} spectrogram parquets')

def picklesave(obj,file):
    ff = open(file,'wb')
    pickle.dump(obj,ff)
    ff.close()

def pickleload(file):
    ff = open(file,'rb')
    obj = pickle.load(ff)
    ff.close()
    return obj


spectrograms = {}
for i,f in enumerate(tqdm(files)):
    if i%100==0: print(i,', ',end='')
    tmp = pd.read_parquet(f'{PATH}{f}')
    name = int(f.split('.')[0])
    spectrograms[name] = tmp.fillna(-1).values[:, 1:].T
    
picklesave(spectrograms,'specs.pkl')
# Out:
# There are 10428 spectrogram parquets
#   0%|          | 0/10428 [00:00<?, ?it/s]
# 0 , 100 , 200 , 300 , 400 , 500 , 600 , 700 , 800 , 900 , 1000 , 1100 , 1200 , 1300 , 1400 , 1500 , 1600 , 1700 , 1800 , 1900 , 2000 , 2100 , 2200 , 2300 , 2400 , 2500 , 2600 , 2700 , 2800 , 2900 , 3000 , 3100 , 3200 , 3300 , 3400 , 3500 , 3600 , 3700 , 3800 , 3900 , 4000 , 4100 , 4200 , 4300 , 4400 , 4500 , 4600 , 4700 , 4800 , 4900 , 5000 , 5100 , 5200 , 5300 , 5400 , 5500 , 5600 , 5700 , 5800 , 5900 , 6000 , 6100 , 6200 , 6300 , 6400 , 6500 , 6600 , 6700 , 6800 , 6900 , 7000 , 7100 , 7200 , 7300 , 7400 , 7500 , 7600 , 7700 , 7800 , 7900 , 8000 , 8100 , 8200 , 8300 , 8400 , 8500 , 8600 , 8700 , 8800 , 8900 , 9000 , 9100 , 9200 , 9300 , 9400 , 9500 , 9600 , 9700 , 9800 , 9900 , 10000 , 10100 , 10200 , 10300 , 10400 ,
